# %%
#   Predict the price of the Uber ride from a given pickup point to the agreed drop-off location. 
# Perform following tasks: 
# 1.  Pre-process the dataset. 
# 2.  Identify outliers. 
# 3.  Check the correlation. 
# 4.  Implement linear regression and random forest regression models. 
# 5.  Evaluate the models and compare their respective scores like R2, RMSE, etc. 
# Dataset link: https://www.kaggle.com/datasets/yasserh/uber-fares-dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pylab
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
from sklearn import preprocessing

# %%
df = pd.read_csv("D:\\Projects\\UBER.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
df.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
df.describe()
# Out:
#          Unnamed: 0    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967154        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# 25%           -73.991407         40.733823         1.000000
# 50%           -73.980093         40.753042         1.000000
# 75%           -73.963658         40.768001         2.000000
# max          1153.572603        872.697628       208.000000

# %%
df = df.drop(['Unnamed: 0', 'key'], axis =1)

# %%
df.isna().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.dtypes
# Out:
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
df.pickup_datetime = pd.to_datetime(df.pickup_datetime, errors='coerce')

# %%
df = df.assign(
    second = df.pickup_datetime.dt.second,
    minute = df.pickup_datetime.dt.minute,
    hour = df.pickup_datetime.dt.hour,
    day = df.pickup_datetime.dt.day,
    month = df.pickup_datetime.dt.month,
    year = df.pickup_datetime.dt.year,
    dayofweek = df.pickup_datetime.dt.dayofweek,
)
df = df.drop('pickup_datetime',axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 199999 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        199999 non-null  float64
#  1   pickup_longitude   199999 non-null  float64
#  2   pickup_latitude    199999 non-null  float64
#  3   dropoff_longitude  199999 non-null  float64
#  4   dropoff_latitude   199999 non-null  float64
#  5   passenger_count    199999 non-null  int64
#  6   second             199999 non-null  int32
#  7   minute             199999 non-null  int32
#  8   hour               199999 non-null  int32
#  9   day                199999 non-null  int32
#  10  month              199999 non-null  int32
#  11  year               199999 non-null  int32
#  12  dayofweek          199999 non-null  int32
# dtypes: float64(5), int32(7), int64(1)
# memory usage: 16.0 MB

# %%
df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  second  minute  hour  day  month  year  \
# 0         40.723217                1       6      52    19    7      5  2015
# 1         40.750325                1      56       4    20   17      7  2009
# 2         40.772647                1       0      45    21   24      8  2009
# 3         40.803349                3      21      22     8   26      6  2009
# 4         40.761247                5       0      47    17   28      8  2014
#
#    dayofweek
# 0          3
# 1          4
# 2          0
# 3          4
# 4          3

# %%
incorrect_coordinates = df.loc[
    (df.pickup_latitude > 90) | (df.pickup_latitude < -90) | 
    (df.dropoff_latitude > 90) | (df.dropoff_latitude < -90) | 
    (df.pickup_longitude > 180) | (df.pickup_longitude < -180) | 
    (df.pickup_longitude > 90) | (df.pickup_longitude < -90)  
    ]
df.drop(incorrect_coordinates, inplace = True, errors = 'ignore')

# %%
def distance_tranform(longitude1, latitude1, longitude2, latitude2):
    long1, lati1, long2, lati2 = map(np.radians, [longitude1, latitude1, longitude2, latitude2])
    dist_long = long2-long1
    dist_lati = lati2-lati1
    a = np.sin(dist_lati/2)**2 + np.cos(lati1) * np.cos(lati2) * np.sin(dist_long/2)**2
    c = 2*np.arcsin(np.sqrt(a))*6371 
    return c

# %%
df['Distance'] = distance_tranform(
    df['pickup_longitude'], df['pickup_latitude'],
    df['dropoff_latitude'], df['dropoff_longitude']
)

# %%
df.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  second  minute  hour  day  month  year  \
# 0         40.723217                1       6      52    19    7      5  2015
# 1         40.750325                1      56       4    20   17      7  2009
# 2         40.772647                1       0      45    21   24      8  2009
# 3         40.803349                3      21      22     8   26      6  2009
# 4         40.761247                5       0      47    17   28      8  2014
#
#    dayofweek      Distance
# 0          3  15079.862708
# 1          4  15079.559294
# 2          0  15082.496925
# 3          4  15087.693292
# 4          3  15079.870287

# %%
plt.scatter(df['Distance'], df['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("Fare_Amount")
# Out:
# Text(0, 0.5, 'Fare_Amount')

# %%
plt.figure(figsize=(20,12))
sns.boxplot(data=df)
# Out:
# <Axes: >

# %%
df.drop(df[df['Distance'] >= 60].index, inplace = True)
df.drop(df[df['fare_amount'] <= 0].index, inplace = True)
df.drop(df[(df['fare_amount']>100) & (df['Distance']<1)].index, inplace = True )
df.drop(df[(df['fare_amount']<100) & (df['Distance']>100)].index, inplace = True )

# %%
plt.scatter(df['Distance'], df['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("fare_amount")
# Out:
# Text(0, 0.5, 'fare_amount')

# %%
corr = df.corr()
corr.style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_4ea39_row0_col0, #T_4ea39_row1_col1, #T_4ea39_row2_col2, #T_4ea39_row3_col3, #T_4ea39_row4_col4, #T_4ea39_row5_col5, #T_4ea39_row6_col6, #T_4ea39_row7_col7, #T_4ea39_row8_col8, #T_4ea39_row9_col9, #T_4ea39_row10_col10, #T_4ea39_row11_col11, #T_4ea39_row12_col12, #T_4ea39_row13_col13 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_4ea39_row0_col1, #T_4ea39_row5_col2, #T_4ea39_row5_col3, #T_4ea39_row11_col1 {
#   background-color: #9cd9ca;
#   color: #000000;
# }
# #T_4ea39_row0_col2, #T_4ea39_row7_col1, #T_4ea39_row9_col1, #T_4ea39_row12_col2 {
#   background-color: #9ad8ca;
#   color: #000000;
# }
# #T_4ea39_row0_col3, #T_4ea39_row8_col1, #T_4ea39_row9_col2, #T_4ea39_row9_col3, #T_4ea39_row12_col1 {
#   background-color: #a0dbcd;
#   color: #000000;
# }
# #T_4ea39_row0_col4, #T_4ea39_row5_col4, #T_4ea39_row10_col3 {
#   background-color: #aadfd3;
#   color: #000000;
# }
# #T_4ea39_row0_col5, #T_4ea39_row4_col5, #T_4ea39_row9_col6 {
#   background-color: #d9f1f0;
#   color: #000000;
# }
# #T_4ea39_row0_col6, #T_4ea39_row9_col5, #T_4ea39_row13_col6 {
#   background-color: #def2f4;
#   color: #000000;
# }
# #T_4ea39_row0_col7, #T_4ea39_row3_col2, #T_4ea39_row11_col7, #T_4ea39_row13_col9 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_4ea39_row0_col8 {
#   background-color: #eef8fb;
#   color: #000000;
# }
# #T_4ea39_row0_col9, #T_4ea39_row2_col0, #T_4ea39_row3_col0, #T_4ea39_row4_col3, #T_4ea39_row5_col0, #T_4ea39_row5_col7, #T_4ea39_row6_col10 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_4ea39_row0_col10, #T_4ea39_row5_col12, #T_4ea39_row8_col10, #T_4ea39_row13_col3, #T_4ea39_row13_col12 {
#   background-color: #e6f5f9;
#   color: #000000;
# }
# #T_4ea39_row0_col11, #T_4ea39_row6_col11 {
#   background-color: #d1eee9;
#   color: #000000;
# }
# #T_4ea39_row0_col12, #T_4ea39_row6_col8 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_4ea39_row0_col13, #T_4ea39_row5_col13 {
#   background-color: #c5e9e2;
#   color: #000000;
# }
# #T_4ea39_row1_col0, #T_4ea39_row4_col0, #T_4ea39_row10_col0, #T_4ea39_row12_col9, #T_4ea39_row13_col0 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_4ea39_row1_col2, #T_4ea39_row1_col4, #T_4ea39_row1_col13, #T_4ea39_row2_col1, #T_4ea39_row2_col3, #T_4ea39_row3_col13, #T_4ea39_row5_col6, #T_4ea39_row6_col5, #T_4ea39_row7_col9, #T_4ea39_row8_col0, #T_4ea39_row8_col12, #T_4ea39_row9_col7, #T_4ea39_row10_col11, #T_4ea39_row11_col10, #T_4ea39_row12_col8 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_4ea39_row1_col3, #T_4ea39_row3_col1 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_4ea39_row1_col5, #T_4ea39_row3_col5 {
#   background-color: #d5efed;
#   color: #000000;
# }
# #T_4ea39_row1_col6, #T_4ea39_row3_col6 {
#   background-color: #dbf1f1;
#   color: #000000;
# }
# #T_4ea39_row1_col7, #T_4ea39_row1_col9, #T_4ea39_row3_col7, #T_4ea39_row3_col9, #T_4ea39_row6_col9, #T_4ea39_row7_col0, #T_4ea39_row8_col7, #T_4ea39_row10_col7, #T_4ea39_row12_col7 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_4ea39_row1_col8, #T_4ea39_row1_col10, #T_4ea39_row1_col12, #T_4ea39_row3_col8, #T_4ea39_row3_col10, #T_4ea39_row3_col12, #T_4ea39_row6_col12 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_4ea39_row1_col11, #T_4ea39_row2_col8, #T_4ea39_row3_col11, #T_4ea39_row4_col8, #T_4ea39_row7_col10, #T_4ea39_row9_col12, #T_4ea39_row10_col12, #T_4ea39_row11_col8, #T_4ea39_row12_col11 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_4ea39_row2_col4, #T_4ea39_row4_col2 {
#   background-color: #00471c;
#   color: #f1f1f1;
# }
# #T_4ea39_row2_col5, #T_4ea39_row13_col5 {
#   background-color: #daf1f1;
#   color: #000000;
# }
# #T_4ea39_row2_col6, #T_4ea39_row4_col6, #T_4ea39_row7_col6, #T_4ea39_row12_col6 {
#   background-color: #dcf2f2;
#   color: #000000;
# }
# #T_4ea39_row2_col7, #T_4ea39_row4_col1, #T_4ea39_row4_col7, #T_4ea39_row9_col0, #T_4ea39_row13_col7 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_4ea39_row2_col9, #T_4ea39_row6_col7 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_4ea39_row2_col10, #T_4ea39_row4_col10, #T_4ea39_row5_col10, #T_4ea39_row8_col11, #T_4ea39_row10_col6, #T_4ea39_row12_col10, #T_4ea39_row13_col8, #T_4ea39_row13_col10 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_4ea39_row2_col11, #T_4ea39_row2_col12, #T_4ea39_row4_col12, #T_4ea39_row5_col8, #T_4ea39_row7_col8, #T_4ea39_row7_col11, #T_4ea39_row7_col12, #T_4ea39_row10_col8, #T_4ea39_row11_col12 {
#   background-color: #e8f6fa;
#   color: #000000;
# }
# #T_4ea39_row2_col13 {
#   background-color: #016e2d;
#   color: #f1f1f1;
# }
# #T_4ea39_row3_col4, #T_4ea39_row6_col0, #T_4ea39_row11_col9 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_4ea39_row4_col9, #T_4ea39_row5_col9, #T_4ea39_row10_col9 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_4ea39_row4_col11, #T_4ea39_row9_col8, #T_4ea39_row9_col11 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_4ea39_row4_col13 {
#   background-color: #006b2b;
#   color: #f1f1f1;
# }
# #T_4ea39_row5_col1 {
#   background-color: #94d6c5;
#   color: #000000;
# }
# #T_4ea39_row5_col11 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_4ea39_row6_col1 {
#   background-color: #9ddacb;
#   color: #000000;
# }
# #T_4ea39_row6_col2, #T_4ea39_row11_col2 {
#   background-color: #9fdacc;
#   color: #000000;
# }
# #T_4ea39_row6_col3, #T_4ea39_row7_col4, #T_4ea39_row10_col1 {
#   background-color: #a4dccf;
#   color: #000000;
# }
# #T_4ea39_row6_col4, #T_4ea39_row11_col4 {
#   background-color: #b0e1d6;
#   color: #000000;
# }
# #T_4ea39_row6_col13 {
#   background-color: #ccece6;
#   color: #000000;
# }
# #T_4ea39_row7_col2 {
#   background-color: #95d6c6;
#   color: #000000;
# }
# #T_4ea39_row7_col3, #T_4ea39_row11_col3 {
#   background-color: #a2dcce;
#   color: #000000;
# }
# #T_4ea39_row7_col5 {
#   background-color: #d6f0ee;
#   color: #000000;
# }
# #T_4ea39_row7_col13, #T_4ea39_row11_col6 {
#   background-color: #bde6de;
#   color: #000000;
# }
# #T_4ea39_row8_col2 {
#   background-color: #97d7c7;
#   color: #000000;
# }
# #T_4ea39_row8_col3, #T_4ea39_row8_col4 {
#   background-color: #a7ddd1;
#   color: #000000;
# }
# #T_4ea39_row8_col5, #T_4ea39_row10_col5 {
#   background-color: #d8f0ef;
#   color: #000000;
# }
# #T_4ea39_row8_col6 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_4ea39_row8_col9 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_4ea39_row8_col13 {
#   background-color: #bfe7de;
#   color: #000000;
# }
# #T_4ea39_row9_col4 {
#   background-color: #b2e2d7;
#   color: #000000;
# }
# #T_4ea39_row9_col10, #T_4ea39_row13_col11 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_4ea39_row9_col13 {
#   background-color: #c8ebe4;
#   color: #000000;
# }
# #T_4ea39_row10_col2 {
#   background-color: #98d8c9;
#   color: #000000;
# }
# #T_4ea39_row10_col4, #T_4ea39_row12_col3 {
#   background-color: #a8ded2;
#   color: #000000;
# }
# #T_4ea39_row10_col13 {
#   background-color: #c2e8e0;
#   color: #000000;
# }
# #T_4ea39_row11_col0 {
#   background-color: #ddf2f3;
#   color: #000000;
# }
# #T_4ea39_row11_col5 {
#   background-color: #e1f4f6;
#   color: #000000;
# }
# #T_4ea39_row11_col13 {
#   background-color: #cdece6;
#   color: #000000;
# }
# #T_4ea39_row12_col0 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_4ea39_row12_col4 {
#   background-color: #acdfd4;
#   color: #000000;
# }
# #T_4ea39_row12_col5 {
#   background-color: #d7f0ee;
#   color: #000000;
# }
# #T_4ea39_row12_col13 {
#   background-color: #c0e7df;
#   color: #000000;
# }
# #T_4ea39_row13_col1 {
#   background-color: #e3f4f7;
#   color: #000000;
# }
# #T_4ea39_row13_col2 {
#   background-color: #00682a;
#   color: #f1f1f1;
# }
# #T_4ea39_row13_col4 {
#   background-color: #006729;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4ea39">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ea39_level0_col0" class="col_heading level0 col0" >fare_amount</th>
#       <th id="T_4ea39_level0_col1" class="col_heading level0 col1" >pickup_longitude</th>
#       <th id="T_4ea39_level0_col2" class="col_heading level0 col2" >pickup_latitude</th>
#       <th id="T_4ea39_level0_col3" class="col_heading level0 col3" >dropoff_longitude</th>
#       <th id="T_4ea39_level0_col4" class="col_heading level0 col4" >dropoff_latitude</th>
#       <th id="T_4ea39_level0_col5" class="col_heading le

# %%
X = df['Distance'].values.reshape(-1, 1) 
y = df['fare_amount'].values.reshape(-1, 1)

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
y_std = std.fit_transform(y)
print(y_std)
x_std = std.fit_transform(X)
print(x_std)
# Out:
# [[-0.86084093]
#  [-0.28867153]
#  [-0.52707545]
#  ...
#  [-0.47939466]
#  [ 0.09277473]
#  [ 2.61985625]]
# [[-0.03014867]
#  [-0.03014867]
#  [-0.03014867]
#  ...
#  [-0.03014867]
#  [-0.03014867]
#  [-0.03014867]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_std, y_std, test_size=0.5, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
l_reg = LinearRegression()
l_reg.fit(X_train, y_train)
print("Training set score: {:.2f}".format(l_reg.score(X_train, y_train)))
print("Test set score: {:.7f}".format(l_reg.score(X_test, y_test)))
# Out:
# Training set score: 0.00
# Test set score: -0.0042463

# %%
y_pred = l_reg.predict(X_test)
result = pd.DataFrame()
result[['Actual']] = y_test
result[['Predicted']] = y_pred
result.sample(10)
# Out:
#         Actual  Predicted
# 1434  1.122680   0.031336
# 1138 -0.136093   0.031336
# 121  -0.670118   0.031336
# 701  -0.097948   0.031336
# 1511 -0.441250   0.031336
# 192   6.529680   0.031336
# 209  -0.364961   0.031336
# 1197 -0.708262   0.031336
# 253  -0.174238   0.031336
# 694  -0.670118   0.031336

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Absolute % Error:', metrics.mean_absolute_percentage_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R Squared (R²):', np.sqrt(metrics.r2_score(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.600682700276531
# Mean Absolute % Error: 1.195809736237779
# Mean Squared Error: 0.9278081548609847
# Root Mean Squared Error: 0.9632279869589466
# R Squared (R²): nan
# C:\Users\KHUSI\AppData\Local\Temp\ipykernel_5256\160152491.py:5: RuntimeWarning: invalid value encountered in sqrt
#   print('R Squared (R²):', np.sqrt(metrics.r2_score(y_test, y_pred)))

# %%
plt.subplot(2, 2, 1)
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, l_reg.predict(X_train), color ="blue")
plt.title("Fare vs Distance (Training Set)")
plt.ylabel("fare_amount")
plt.xlabel("Distance")
plt.subplot(2, 2, 2)
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, l_reg.predict(X_train), color ="blue")
plt.ylabel("fare_amount")
plt.xlabel("Distance")
plt.title("Fare vs Distance (Test Set)")
plt.tight_layout()
plt.show()

# %%
cols = ['Model', 'RMSE', 'R-Squared']
# create a empty dataframe of the colums
# columns: specifies the columns to be selected
result_tabulation = pd.DataFrame(columns = cols)
# compile the required information
linreg_metrics = pd.DataFrame([[
"Linear Regresion model",
np.sqrt(metrics.mean_squared_error(y_test, y_pred)),
np.sqrt(metrics.r2_score(y_test, y_pred))
]], columns = cols)
result_tabulation = pd.concat([result_tabulation, linreg_metrics], ignore_index=True)
result_tabulation
# Out:
# C:\Users\KHUSI\AppData\Local\Temp\ipykernel_5256\3905207923.py:9: RuntimeWarning: invalid value encountered in sqrt
#   np.sqrt(metrics.r2_score(y_test, y_pred))
# C:\Users\KHUSI\AppData\Local\Temp\ipykernel_5256\3905207923.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   result_tabulation = pd.concat([result_tabulation, linreg_metrics], ignore_index=True)
#                     Model      RMSE  R-Squared
# 0  Linear Regresion model  0.963228        NaN

# %%
rf_reg = RandomForestRegressor(n_estimators=100, random_state=10)
# fit the regressor with training dataset
rf_reg.fit(X_train, y_train)
# Out:
# C:\Users\KHUSI\AppData\Local\Temp\ipykernel_5256\3707646596.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_reg.fit(X_train, y_train)
# RandomForestRegressor(random_state=10)

# %%
# predict the values on test dataset using predict()
y_pred_RF = rf_reg.predict(X_test)
result = pd.DataFrame()
result[['Actual']] = y_test
result['Predicted'] = y_pred_RF
result.sample(10)
# Out:
#         Actual  Predicted
# 284  -0.097948   0.030747
# 1156 -0.403105   0.030747
# 99   -0.336352   0.030747
# 1579 -0.746407   0.030747
# 954   0.569583   0.030747
# 1388 -0.860841   0.030747
# 1567 -0.288672   0.030747
# 199  -0.593829   0.030747
# 1060  3.859557   0.030747
# 735  -0.527075   0.030747

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_RF))
print('Mean Absolute % Error:', metrics.mean_absolute_percentage_error(y_test, y_pred_RF))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_RF))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_RF)))
print('R Squared (R²):', np.sqrt(metrics.r2_score(y_test, y_pred_RF)))
# Out:
# Mean Absolute Error: 0.6002588037194034
# Mean Absolute % Error: 1.1917375416731626
# Mean Squared Error: 0.9274433989220873
# Root Mean Squared Error: 0.9630386279491011
# R Squared (R²): nan
# C:\Users\KHUSI\AppData\Local\Temp\ipykernel_5256\1153566439.py:5: RuntimeWarning: invalid value encountered in sqrt
#   print('R Squared (R²):', np.sqrt(metrics.r2_score(y_test, y_pred_RF)))

# %%
# Build scatterplot
plt.scatter(X_test, y_test, c = 'b', alpha = 0.5, marker = '.', label = 'Real')
plt.scatter(X_test, y_pred_RF, c = 'r', alpha = 0.5, marker = '.', label = 'Predicted')
plt.xlabel('Carat')
plt.ylabel('Price')
plt.grid(color = '#D3D3D3', linestyle = 'solid')
plt.legend(loc = 'lower right')
plt.tight_layout()
plt.show()

# %%
# compile the required information
random_forest_metrics = pd.DataFrame([[
"Random Forest Regressor model",
np.sqrt(metrics.mean_squared_error(y_test, y_pred_RF)),
np.sqrt(metrics.r2_score(y_test, y_pred_RF))
]], columns = cols)
result_tabulation = pd.concat([result_tabulation, random_forest_metrics], ignore_index=True)
result_tabulation
# Out:
# C:\Users\KHUSI\AppData\Local\Temp\ipykernel_5256\2636426006.py:5: RuntimeWarning: invalid value encountered in sqrt
#   np.sqrt(metrics.r2_score(y_test, y_pred_RF))
#                            Model      RMSE  R-Squared
# 0         Linear Regresion model  0.963228        NaN
# 1  Random Forest Regressor model  0.963039        NaN
